# %% [markdown]
# Import

# %%
import pandas as pd

# %%
thiel_investments = [
    "Clearview AI",
    "Xero",
    "Y Combinator",
    "Mithril Capital",
    "Valar Ventures",
    "Founders Fund",
    "Facebook",
    "Airbnb",
    "Slide.com",
    "LinkedIn",
    "Friendster",
    "RapLeaf",
    "Geni.com",
    "Yammer",
    "Yelp Inc.",
    "Spotify",
    "Powerset",
    "Practice Fusion",
    "MetaMed",
    "Vator",
    "SpaceX",
    "Palantir Technologies",
    "IronPort",
    "Votizen",
    "Asana",
    "Big Think",
    "CapLinked",
    "Quora",
    "Nanotronics Imaging",
    "Rypple",
    "TransferWise",
    "Stripe",
    "Block.one",
    "AltSchool",
]
levchin = ["Slide", "Yelp", "Affirm", "Glow", "HVF", "Kaggle", "Wise"]
musk_investments = [
    "xAI",
    "Zip2",
    "X.com",
    "SpaceX",
    "Tesla",
    "Deep Mind",
    "OpenAI",
    "NeuroVigil",
    "SolarCity",
    "Neuralink",
    "The Boring Company",
    "Twitter",
]
mclure = [
    "Credit Karma",
    "Canva",
    "Lyft",
    "Creditas",
    "Udemy",
    "SmileDirectClub",
    "Talkdesk",
    "GitLab",
]
banister = [
    "Powerset",
    "eVoice",
    "IronPort",
    "Uber",
    "Zappos.com",
    "LiveOps",
    "Facebook",
    "Hi5.com",
    "Tagged.com",
    "iLike",
    "Causes.com",
    "Topsy Labs",
    "Teleport",
    "Inc.",
    "TekTrak",
]
sacks = [
    "Geni.com",
    "Yammer",
    "Zenefits",
    "Addepar",
    "Affirm",
    "Airbnb",
    "Bird",
    "Clutter",
    "Eventbrite",
    "Facebook",
    "Gusto",
    "Houzz",
    "Intercom",
    "Mixpanel",
    "Opendoor",
    "Palantir Technologies",
    "Postmates",
    "ResearchGate",
    "Rumble",
    "Scribd",
    "Slack",
    "SpaceX",
    "SurveyMonkey",
    "ThirdLove",
    "Uber",
    "Wish",
]
rabois = [
    "LinkedIn",
    "Square",
    "Khosla Ventures",
    "Scribd",
    "Opendoor",
    "Founders Fund",
]
hoffman = [
    "LinkedIn",
    "Greylock Partners",
    "Facebook",
    "Airbnb",
    "ZipCar",
    "Pandora",
    "Edmodo",
    "Groupon",
    "Convoy",
    "Zynga",
    "Flickr",
    "Shopkick",
    "Kiva",
    "Nauto",
]

# %%
hoppelman = [
    "Yelp",
    "Future",
    "PlanetScale",
    "Netlify",
    "JoyTunes",
    "Microbiome Therapeutics",
    "IfOnly",
    "Quartzy",
    "Pathlight",
    "Seed",
    "8i",
    "NextLesson",
    "HackerOne",
    "Honor",
    "Lever",
    "Opendoor",
    "Slack",
    "Confide",
    "Iodine",
    "Envoy",
    "Minted",
    "Liftopia",
    "Gusto",
    "Beautylish",
    "Airbnb",
    "Uber",
    "inDinero",
    "Udemy",
    "Palantir Technologies",
    "Pinterest",
]
